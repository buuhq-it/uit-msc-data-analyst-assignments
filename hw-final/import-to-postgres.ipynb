# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
#  Kết nối tới PostgreSQL
engine = create_engine('postgresql+psycopg2://postgres:Password123@localhost:5432/home_credit_risk')

# %%
# Load và ghi từng file CSV vào bảng
df = pd.read_csv('dataset/application_train.csv')
# df.head()
df.to_sql('application_train', engine, index=False, if_exists='replace')
# Out:
# 115
