# %%
from pandas import read_excel
from statsmodels.formula.api import ols

# %%
df =  read_excel("hw1-group11-regression-excel.xlsx", sheet_name="data")
df.head()
# Out:
#                                              Address     Province  \
# 0  Dự án Khu đô thị Phương Đông, Xã Đông Xá, Vân ...   Quảng Ninh
# 1  Đường Quang Trung, Phường 12, Gò Vấp, Hồ Chí Minh  Hồ Chí Minh
# 2  Đường Ngô Tất Tố, Phường 22, Bình Thạnh, Hồ Ch...  Hồ Chí Minh
# 3  Dự án Vườn Vua Resort & Villas, Đường 316, Xã ...      Phú Thọ
# 4  Dự án The Empire - Vinhomes Ocean Park 2, Xã L...     Hưng Yên
#
#   House direction Balcony direction      Legal status Furniture state   Area  \
# 0            Đông               Nam  Have certificate            Full  300.0
# 1      Đông - Nam        Đông - Nam  Have certificate            Full   46.0
# 2      Đông - Nam              Đông  Have certificate            Full   60.0
# 3      Đông - Nam        Đông - Nam  Have certificate            Full  369.0
# 4      Đông - Nam        Đông - Nam  Have certificate           Basic   78.0
#
#    Frontage  Access Road  Floors  Bedrooms  Bathrooms  Price
# 0      15.0         32.0       3         6          3   9.40
# 1       4.6          6.0       4         4          5   7.99
# 2       3.5          5.0       2         6          5   5.60
# 3      15.0         12.0       2         4          4   6.30
# 4       6.0         13.0       4         6          6   8.63

# %%
df.columns = [col.replace(' ', '') for col in df.columns]
df.head()
# Out:
#                                              Address     Province  \
# 0  Dự án Khu đô thị Phương Đông, Xã Đông Xá, Vân ...   Quảng Ninh
# 1  Đường Quang Trung, Phường 12, Gò Vấp, Hồ Chí Minh  Hồ Chí Minh
# 2  Đường Ngô Tất Tố, Phường 22, Bình Thạnh, Hồ Ch...  Hồ Chí Minh
# 3  Dự án Vườn Vua Resort & Villas, Đường 316, Xã ...      Phú Thọ
# 4  Dự án The Empire - Vinhomes Ocean Park 2, Xã L...     Hưng Yên
#
#   Housedirection Balconydirection       Legalstatus Furniturestate   Area  \
# 0           Đông              Nam  Have certificate           Full  300.0
# 1     Đông - Nam       Đông - Nam  Have certificate           Full   46.0
# 2     Đông - Nam             Đông  Have certificate           Full   60.0
# 3     Đông - Nam       Đông - Nam  Have certificate           Full  369.0
# 4     Đông - Nam       Đông - Nam  Have certificate          Basic   78.0
#
#    Frontage  AccessRoad  Floors  Bedrooms  Bathrooms  Price
# 0      15.0        32.0       3         6          3   9.40
# 1       4.6         6.0       4         4          5   7.99
# 2       3.5         5.0       2         6          5   5.60
# 3      15.0        12.0       2         4          4   6.30
# 4       6.0        13.0       4         6          6   8.63

# %%
model = ols("Price ~ Area + Frontage + AccessRoad + Floors + Bedrooms + Bathrooms", data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.284
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     174.1
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):          5.54e-187
# Time:                        11:37:37   Log-Likelihood:                -5445.7
# No. Observations:                2645   AIC:                         1.091e+04
# Df Residuals:                    2638   BIC:                         1.095e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.5014      0.146     10.294      0.000       1.215       1.787
# Area           0.0081      0.001      9.125      0.000       0.006       0.010
# Frontage      -0.0059      0.008     -0.739      0.460      -0.021       0.010
# AccessRoad     0.0473      0.005      9.081      0.000       0.037       0.058
# Floors         0.2621      0.041      6.342      0.000       0.181       0.343
# Bedrooms       0.1442      0.049      2.972      0.003       0.049       0.239
# Bathrooms      0.5068      0.046     10.961      0.000       0.416       0.597
# ==============================================================================
# Omnibus:                       55.937   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.853
# Skew:                           0.339   Prob(JB):                     4.51e-13
# Kurtosis:                       2.763   Cond. No.                         351.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
