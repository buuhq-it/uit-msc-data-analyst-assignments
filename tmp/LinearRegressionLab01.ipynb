# %%
from pandas import read_csv, get_dummies, read_excel
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols

# %%
df_train =  read_excel("housing_data_preprocessor.xlsx", sheet_name="train_data")
df_train.head()
# Out:
#                                              Address  ... Price
# 0     Đường Cổ Điển A, Xã Tứ Hiệp, Thanh Trì, Hà Nội  ...  3.45
# 1                     Phường Hà Cầu, Hà Đông, Hà Nội  ...  9.60
# 2  Phố Tôn Đức Thắng, Phường Hàng Bột, Đống Đa,...  ...  8.50
# 3  Đường Vành Đai 3.5, Xã Vân Canh, Hoài Đức, Hà Nội  ...  5.40
# 4  Dự án Centa Riverside, Đường Hữu Nghị, Phường ...  ...  9.00
#
# [5 rows x 13 columns]

# %%
df_train.columns = [col.replace(' ', '') for col in df_train.columns]

# %%
# df_train, df_test = train_test_split(df)

# %%
df_train.head()
# Out:
#                                              Address  ... Price
# 0     Đường Cổ Điển A, Xã Tứ Hiệp, Thanh Trì, Hà Nội  ...  3.45
# 1                     Phường Hà Cầu, Hà Đông, Hà Nội  ...  9.60
# 2  Phố Tôn Đức Thắng, Phường Hàng Bột, Đống Đa,...  ...  8.50
# 3  Đường Vành Đai 3.5, Xã Vân Canh, Hoài Đức, Hà Nội  ...  5.40
# 4  Dự án Centa Riverside, Đường Hữu Nghị, Phường ...  ...  9.00
#
# [5 rows x 13 columns]

# %%
model = ols("Price ~ Area + Frontage + AccessRoad + Floors + Bedrooms + Bathrooms", data = df_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.289
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                     134.1
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):          1.11e-142
# Time:                        16:23:40   Log-Likelihood:                -4081.5
# No. Observations:                1983   AIC:                             8177.
# Df Residuals:                    1976   BIC:                             8216.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4657      0.170      8.607      0.000       1.132       1.800
# ...
