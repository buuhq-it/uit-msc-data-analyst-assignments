# %%
import pmdarima

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data
df = pd.read_csv('toy_example_data.csv')

## Fitting the model
arima_fit = pmdarima.auto_arima(df['Y'], error_action='ignore', suppress_warnings=True, seasonal=True)

## Printing a summary of the model
arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  117
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                 -60.745
# Date:                Tue, 12 Apr 2022   AIC                            133.490
# Time:                        21:28:54   BIC                            150.012
# Sample:                             0   HQIC                           140.197
#                                 - 117
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0331      0.021      1.588      0.112      -0.008       0.074
# ar.L1          1.0627      0.138      7.683      0.000       0.792       1.334
# ar.L2         -0.4351      0.138     -3.151      0.002      -0.706      -0.164
# ...
